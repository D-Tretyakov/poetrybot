# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
import json
# Out:
# Using TensorFlow backend.
# /home/rokku/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/rokku/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/rokku/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/rokku/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/rokku/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/rokku/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/rokku/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/rokku/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/rokku/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/rokku/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/rokku/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/rokku/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
with open('./ALL_SDX_REV.txt', encoding='utf-8') as f:
    text = f.read()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# corpus length: 1231957
# total chars: 24
# nb sequences: 410639

# %%
model = load_model('lermonet_2.h5')
# Out:
# WARNING:tensorflow:From /home/rokku/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
diversity = 1.0

# %%
def generate_rnn(count):
    generated = ""
    start_index = random.randint(0, len(text) - maxlen - 1)
    sentence = text[start_index: start_index + maxlen]
    generated += sentence

    for i in range(count):
        x = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x[0, t, char_indices[char]] = 1.

        preds = model.predict(x, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char
    return generated

# %%
print(generate_rnn(2000))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# 5A3 A1428B8A4B7Ь8AJ V1264AB4 / S251B9B3A3A S018B V14B6A1A5B6 / A2242B98A S012A4Ь A13A19A2AJ A0126A8 P027Ь V228A37C6Ь C01B C0154AJ S22JB3A / V22649B7A V0349A642A2A4 S1339C64B7B6 / A131A8A2AJ S22C64A8 P011A V011A7 P018B P01A S014C8 P018B3 / S133A8B4A A22A48B / S1262A8A2 P0147A S2219B63C A02JB5B A2224B6A3 S128B9B / S012637C4 C01B7Ь V1319B68JC A041A68B68JB V236A8A64B2 P018B / A239A3A2AJ S016C4Ь V2263A5B P018B S01JA A014A3 / A227C5BJ V226A9B4 A2226B3A A0162AJ V1217A2A7 / V235A69A6A S023A7A64Ь A138A39A63AJ P01B6 A026A5B8 S018B / S238A85B8A P01C A256B8A67A2JB / S023A78C7 S22A8B S011B / S018A6 P012 V226B2C4 P011C C01B V24A37A6B7A / S23649B8B8A A031C63JB V234B96B27B / S22JB3A S238A7Ь1AJC P013 S01A8 C01B / S2242A9A S031A8C5B A138B2A7Ь8A S2217B8C S01A2 C01B / V141B3B4JC A021A4A3 S0119B4 S224A38B P016 S01A8 / A228B1B8 S0168C A0134B V14A4B4A7B6Ь C01B / S1237C1B A148B2B83B8 V221A3A8 A1219B54B V024B4A4Ь S01A8 S026B3B3 S019A6 C01B / S039AJ3B8A V22649A64A7 P011A S018A8 P011A V018A3 C01B C018B V141A4B95B67B2 S2237C3AC / V12B8B4Ь S1226A48B3 A124B3A V139A4B76A C014A V22JB45B7Ь8B / A22649B18A8 S221AJ6A P012 V138B6A4A / S0139Ь1A8 V227C1B4 V2219A64B8 S238B5A3B / V2419A2B7B7A S142A85B8JA P015 C01B S013A64Ь / S0162C3 A02JC58AJ S1364C5B14A A013A3 / V232A8JA S235A92JC V13A1C4B4Ь V22C8B6 P018B / S021C43A A039C63A3A A1319B4C58AJ A013A3 / S12649A64A3 V1319B3A7A6Ь A138A19A2AJ / S03C49B1BJ P01A4 A232B2B64C / S0139A2Ь A0319A68A68B P016 A234A39A64JC A013A3 / A027C58A S023B4B7 A013A3 V225B4A7 P018B S01JA / S238A3A2A8 A024B63BJ A1267B53B3 C01B / V129C8A A13C4A7Ь3A V2337C1B6A / S227B4A S22JB3A S228C3AJ P015 C0154A / S227C4B V1315B2A7B6Ь A149A4B76A2A / S126A3A S022B58A C01B C01B V142A7B4JC P021B92/ P012A4 V22419A3A6Ь 9135B1A48A / S0137A6 A133A7Ь4B8A8 S014B8Ь A013A3 V221A6A4Ь / S2242A8A S0127A8PЬ 01A37 P018A S01JA C015B8 / S24A5B64A7A8B V138B6B6A / S1249B2B8 A228JA S0139A2Ь S237B48A9A A018AJ C01B / S1249C3A S018B V13A93C4A6Ь A228JBJ S039C63C8B S01A8 S012A A018A5 / A233A7A2AJ V158A24A75JB P018B / V23C49B5B4 C01B A2249C3AJ V0143A7Ь C01B S0Ь4A4 C

# %%
def levenshtein_distance(word1, word2):
    if len(word1) < len(word2):
        return levenshtein_distance(word2, word1)

    if len(word2) == 0:
        return len(word1)

    previous_row = list(range(len(word2) + 1))

    for i, char1 in enumerate(word1):
        current_row = [i + 1]

        for j, char2 in enumerate(word2):
            insertions = previous_row[j + 1] + 1
            deletions = current_row[j] + 1
            substitutions = previous_row[j] + (char1 != char2)

            current_row.append(min(insertions, deletions, substitutions))

        previous_row = current_row
    return previous_row[-1]

# %%
with open('SDX_WORD.txt', 'r') as f:
    sdx_word = json.loads(f.read())

# %%
sdx_word
# Out:
# {'A1339B8C5BJ': 'гремучий',
#  'V14A4B2A7B6Ь': 'одевались',
#  'S237A81A4AJ': 'лампадой',
#  'A034B3JA': 'тихая',
#  'A145A81A863A3A': 'шампанского',
#  'S141A7A5B8JB': 'положенье',
#  'V139A6C4B2': 'рассудив',
#  'S131A4A53B': 'подачки',
#  'V2261B5A': 'спеша',
#  'A048C5B4B7Ь8A': 'мучительна',
#  'A233A3A2A': 'каково',
#  'A133A9A5B': 'короче',
#  'V1319B8B4A': 'приметя',
#  'S013A1Ь': 'копь',
#  'V134A9A1B5Ь': 'торопишь',
#  'V035B15B6A': 'шепчется',
#  'A2263A7AJ': 'скалой',
#  'S141A4A9A5B3': 'подарочек',
#  'V13B61A78B4Ь': 'исполнить',
#  'V032A649B7B7': 'выстрелил',
#  'A04JA6A5B63AJ': 'языческой',
#  'A141A6A98JA': 'позорная',
#  'S021A7Ь1A': 'больпо',
#  'V2369B19B7A6Ь': 'сребрилась',
#  'V241A6A2B4B': 'позовите',
#  'V236A2B98C4': 'завернут',
#  'V2419B8A6B7A': 'приносила',
#  'V2419B8A47B5A4': 'принадлежат',
#  'A248B6B81JB': 'неземпые',
#  'V2419B42B5JB4': 'предвещает',
#  'S22A2A6': 'афос',
#  'V136A8B4B8': 'заметим',
#  'V142A7A3B4AJ': 'волокитой',
#  'A1239B3B': 'греки',
#  'V13B61A2B': 'избави',
#  'V226JA7': 'сеял',
#  'A038B58A8B': 'нежными',
#  'V2364B8JC': 'стенаю',
#  'A138B8A53A': 'немножко',
#  'S013A3': 'гак',
#  'A225B94AJ': 'чертой',
#  'V0124A56Ь': 'вдащсь',
#  'S224C5AJ': 'душой',
#  'V238A1B3C': 'набегу',
#  'V2319B8B5A7': 'примечал',
#  'A044C5B64JA': 'душистая',
#  'V136A64A8B5Ь': 'застанешь',
#  'A046B9B19A8A8': 'серебряным',
#  'V02B8A8': 'ином',
#  'V135B4A7B6Ь': 'считались',
#  'A034B3A3A': 'дикого',
#  'V24C8B9JA': 'умирая',
#  'V2337A4B7B': 'глядели',
#  'S23A9JB93A94': 'арьергард',
#  'S14C8B5B8BJ': 'унижений',
#  'V131A48A25B6Ь': 'поднявшись',
#  'S241B3C5JC': 'бегущею',
#  'A2249C1AJ': 'трубой',
#  'S2238A6BJ': 'князей',
#  'A024B963B3': 'дерзких',
#  'P015': 'ж',
#  'V148A4JA4Ь6A': 'надеяться',
#  'V1264A7A': 'стала',
#  'S145B8A9JC': 'чинарою',
#  'V238A3A4B7': 'находил',
#  'V0164AJ': 'стой',
#  'V2429A83B64A8A': 'франгистана',
#  'A038A5B3AJ': 'мачехой',
#  'A1419B1B9B58A3': 'прибережных',
#  'S128A5A': 'нача',
#  'V2419B7B1A7B': 'прилипали',
#  'V228A4B7': 'надел',
#  'A014AJ': 'дый',
#  'S151A3JA8B': 'покаянии',
#  'A035B74JB': 'желтое',
#  'A1519B19A2A54B8AJ': 'препровожденный',
#  'S144C8A2B8JA': 'дуновенья',
#  'V149A61JA5Ь6A': 'распояшься',
#  'S024B3A64Ь': 'дикость',
#  'V236A39B1B7': 'захрипел',
#  'V0149C31': 'другп',
#  'A13B68B8AJ': 'изменой',
#  'V146A8A7C1JB': 'самолюбье',
#  'A128A4B54': 'надежд',
#  'V13A1B4C': 'обиду',
#  'S131A9A8C': 'барону',
#  'S031B9B3A': 'берега',
#  'V046B8JC5BJ': 'синеющий',
#  'V13A62B4B4': 'осветит',
#  'A1362A5B8AJ': 'священный',
#  'A038A48JA': 'модная',
#  'V026A64A8': 'создан',
#  'S127C5A84': 'лучамд',
#  'V23A42B5A7': 'отвечал',
#  'V149A63A6A2A4Ь': 'рассказывать',
#  'V22A9B7': 'орел',
#  'V234B8JC4': 'темнеют',
#  'V2519A4A8C4JC': 'протянутую',
#  'V223A64B4Ь': 'гостить',
#  'V243A2A9B7B': 'говорили',
#  'V148B8A2B4B4': 'ненавидит',
#  'S13A5B13B': 'ошибки',
#  'S231A5B642C': 'божеству',
#  'P013A': 'ко',
#  'A1263A9AJ': 'скорый',
#  'V131B7JB4': 'белеет',
#  'V2254A7A': 'ждала',
#  'V0168B6Ь': 'смесь',
#  'A024C58A3': 'душных',
#  'V138A4C5B8': 'надушен',
#  'S127A9B': 'лоре',
#  'S243A84B4A4A2': 'кандидатов',
#  'A148B1A42B58A8': 'неподвижным',
#  'V13B61A78B8': 'исполнен',
#  'S123A7A1': 'колопп',
#  'V1319B8A6B4': 'приносит',
#  'V13217B7A6A': 'вплелася',
#  'S128JA': 'мея',
#  'A031B5B8A3': 'бешеных',
#  'V132A3A4B4': 'выходит',
#  'A148A7A4C58A': 'малодушны',
#  'A038B75B2AJ': 'нелживый',
#  'A131B649A58A3': 'бесстрашных',
#  'A036A5B8AJ': 'зажженный',
#  'V14A48A4JC': 'отнятую',
#  'V2261A64B6Ь': 'спастись',
#  'V23C8A7A': 'уныла',
#  'A239A67C3AJ': 'разлукой',
#  'S1319A3A6AJ': 'проказой',
#  'S024A8JC': 'данью',
#  'V14C8B54A5B8': 'уничтожим',
#  'A258B68A3A8JA': 'незнакомая',
#  'V23C8JA': 'умея',
#  'A1468A3A8JB': 'знакомые',
#  'V231A49JA': 'подрая',
#  'S025B4B7Ь': 'житель',
#  'S2269A28C': 'сравню',
#  'V13C8A5B4Ь': 'умножить',
#  'S02B639A': 'искры',
#  'V2319A2A4B7': 'проводил',
#  'S1439A6A2B6A8': 'красавицам',
#  'S131A7A3A8': 'пологом',
#  'S031AJ6A8B': 'бойцами',
#  'S1238B53B': 'книжке',
#  'V13C8B95BJ': 'умерший',
#  'V2237A4B4': 'глядит',
#  'A031B92JC': 'первую',
#  'A146A1C9A2AJ': 'сабуровой',
#  'V23C67A3A4Ь': 'услыхать',
#  'S2264B9B3': 'стерег',
#  'A1349C1A5BJ': 'трубачей',
#  'A134C8A8AJ': 'туманный',
#  'V12649AB4Ь': 'строить',
#  'A146C4Ь1B8C53AJ': 'судьбинушкой',
#  'V127JA': 'лея',
#  'A03JB678': 'еслн',
#  'S034A6A5A': 'тысяча',
#  'A1247B8AJ': 'тленной',
#  'A13A47A68A3': 'атласных',
#  'A1449A3B5B63BJ': 'трагический',
#  'S136A1A4BJ': 'событий',
#  'V015A4Ь': 'жать',
#  'V2219B1B4Ь': 'прибить',
#  'A142A64C58JB': 'воздушные',
#  'V1219A5B64Ь': 'прочесть',
#  'A031A58JA': 'пышная',
#  'A025A64AJ': 'частый',
#  'A224A8A': 'томно',
#  'A1267A5B8': 'слышен',
#  'S234B8JC': 'темною',
#  'P012A': 'во',
#  'S228B7A5': 'милыш',
#  'S1237A9C': 'клару',
#  'S2319B3A2A9': 'приговор',
#  'S129B5B': 'речи',
#  'S228JB8': 'моем',
#  'V13A419A27C': 'отправлю',
#  'V1232A7A': 'хвала',
#  'A131B5A7Ь1AJ': 'печальпый',
#  'S1367A4BJ642A': 'злодейство',
#  'V014AJ': 'дай',
#  'A028A7AJ': 'малой',
#  'S0262B5B64Ь': 'свежесть',
#  'V1239A5BJ': 'крышей',
#  'S231B37B6A': 'беглеца',
#  'A1319JB5BJ': 'проезжий',
#  'P01A1': 'об',
#  'A036A9642B8A3': 'царственных',
#  'V22268A38C7': 'взмахнул',
#  'S2242A96A': 'дворца',
#  'A235A67B2AJ': 'счастливый',
#  'A131A7B8A': 'палимы',
#  'A149A63A7B8AJ': 'раскаленный',
#  'A2218A34A': 'пногда',
#  'V24C2B9JC': 'уверяю',
#  'A02A15BJ': 'общий',
#  'A034AJ8JB': 'тайное',
#  'V2264B95A4Ь': 'сдержать',
#  'A139B28B2A3': 'ревнивых',
#  'S128B8JB': 'мненье',
#  'V239A69C5B1': 'разрушеппп',
#  'S015B73': 'щелк',
#  'V238A649AB4': 'настроит',
#  'V226A1B7': 'забил',
#  'V2263A91B4Ь': 'скорбеть',
#  'A137C1B8A': 'любимы',
#  'A1419B2A7Ь8JB': 'привольное',
#  'V22C8C': 'уму',
#  'S1389A58JC': 'мрачною',
#  'S2242A9B6': 'творец',
#  'S1319B9A4AJ': 'природой',
#  'A2419B3A47B2AJ': 'прихотливый',
#  'A13A6B8BJ': 'осенней',
#  'V124A8A': 'дана',
#  'V24A14B9JA': 'обтирая',
#  'S14A18A85B6A': 'обманщицы',
#  'V2419A1B2A76A': 'пробивался',
#  'A14B619A8JC': 'избранную',
#  'V161A7C6A2A45JB': 'полузавядшие',
#  'A148A7C4B8AJ': 'малютиной',
#  'A1362A1A48A': 'свободно',
#  'A12649A8AJ': 'странный',
#  'S128A5C': 'машу',
#  'S135B9A3C': 'широку',
#  'S023A1B7Ь': 'капель',
#  'V231A8A57A4Ь': 'помышлять',
#  'S2287A4AJ': 'младой',
#  'A138A38C4AJ': 'нагнутый',
#  'V048A1A78B7A6Ь': 'наполнилась',
#  'V123C1B4Ь': 'губить',
#  'V05A4B8A6A4AJ': 'одиннадцатый',
#  'V1337C1JC': 'глупою',
#  'S235A4A94A3': 'чатырдаг',
#  'V13C67A5B5Ь': 'услышишь',
#  'V0363A5C5B3': 'скачущих',
#  'S142B87A84B': 'финляндии',
#  'S238A963JC': 'морскою',
#  'S23B39A3A2': 'игроков',
#  'S02C5B8': 'ужин',
#  'S223A9A': 'коры',
#  'S234C9A3A8': 'дураком',
#  'A134A64AJ8A': 'достойно',
#  'A2468A2B4B8BJ': 'сновидений',
#  'S0326A48B3A2': 'всадников',
#  'S136A8B8JB': 'сомненье',
#  'V223A24A8': 'кафтан',
#  'S1363B1B49A8': 'скипетром',
#  'S018B3': 'мех',
#  'V1264A2Ь4B': 'ставьте',
#  'S023C943B': 'куртки',
#  'S131B64B73B': 'безделке',
#  'S2337C1B8A': 'глубины',
#  'V1363C5JB5Ь': 'скучаешь',
#  'V13C2B4B4': 'увидит',
#  'V151A4B95B2A7B': 'поддерживали',
#  'A236B8A8C': 'земному',
#  'V016B875': 'землщ',
#  'V234A3A9B2': 'догорев',
#  'S2232A64A8': 'хвостом',
#  'A146A67A8B8AJ': 'заслоненный',
#  'S2229A54A': 'вражда',
#  'A04C4B5B8AJ': 'утешенный',
#  'S141JA9A8B': 'боярами',
#  'S0139C64Ь': 'грусть',
#  'V2419B64C1B7A': 'приступила',
#  'V23C8A2A4Ь': 'умывать',
#  'A238B3C4A': 'никуда',
#  'S012B5Ь': 'вещь',
#  'S1439A6A2B6BJ': 'красавицей',
#  '-025A95B': 'жарче',
#  'S15C8B54A5B8JB': 'уничтоженье',
#  'S123A8B': 'кони',
#  'S1319A37A4JB': 'проклятье',
#  'A025B64B8': 'честен',
#  'V135C4B7A6Ь': 'чудилось',
#  'V014A64': 'даст',
#  'A2239B2AJ': 'гривой',
#  'A158B1A8A48JA': 'непонятная',
#  'A031C48B3A8': 'путником',
#  'A135B2A8C': 'живому',
#  'V011B7': 'бил',
#  'V236A8A738B4': 'замолкнет',
#  'V12C8A73': 'умолк',
#  'V241A6C98A8A': 'басурманы',
#  'A146A649B7B8AJ': 'застреленный',
#  'V14637A8B7A6A': 'склонилася',
#  'V2319A8B7B': 'бранили',
#  'V0168A8': 'сном',
#  'V132A69A5BJ': 'возросший',
#  'V13A3A85B2': 'окончив',
#  'V24A42B5JB4': 'отвечает',
#  'S022B49A8': 'ветром',
#  'S0167A2': 'слов',
#  'S031A2B938A64Ь': 'поверхность',
#  'A1339B58JB': 'грешные',
#  'A038B73JB': 'мелкие',
#  'S2339A6A4A': 'красота',
#  'V239A619A8B7': 'разбранил',
#  'S025B43B': 'четки',
#  'V039A4JC4': 'радуют',
#  'A1239A68A': 'грязна',
#  'V1219A5B3': 'прожег',
#  'A038A7A4A': 'молодо',
#  'V132A6B4Ь6A': 'возиться',
#  'S131B5A7JC': 'печалью',
#  'A1268B58A3': 'снежных',
#  'S221A73A2': 'полков',
#  'A13A39A8AJ': 'огромный',
#  'A028B73B3': 'мелких',
#  'S2517A3A67A2B8JB': 'благословенье',
#  'A131A7B68BJ': 'полезней',
#  'V2319B27B3A7': 'привлекал',
#  'S234B1C4A4': 'депутат',
#  'V026C8AJ': 'суммой',
#  'V22A439A7': 'открыл',
#  'S2239C4AJ': 'грудой',
#  'V242A67B4JB4': 'возлетает',
#  'V259A619A649A8A7B6Ь': 'распространялись',
#  'S224A63A': 'доска',
#  'A038B7JC': 'милую',
#  'V1519B42A9JB6A': 'притворяется',
#  'V131A3A48A8': 'походном',
#  'S231A7A5B': 'палачи',
#  'V1417B64A5JA': 'блестящая',
#  'S226B9B3': 'серег',
#  'S136A6B43A': 'соседка',
#  'S227B64A8': 'листам',
#  'V015JC4': 'шьют',
#  'S22C8A8': 'умом',
#  'V2419B8B9B7A': 'примирила',
#  'V2362B93A7A': 'сверкала',
#  'S256A8A1A68A8JA': 'самопознанья',
#  'A04A6B8A2AJ': 'осиновый',
#  'V221B58B4': 'бешмет',
#  'S2239B87A': 'кремля',
#  'V23A12B5A8': 'обвешан',
#  'V0349A8C7A6Ь': 'тронулась',
#  'S146C19C5B642A': 'супружества',
#  'S2519B7A5B8JB': 'приложение',
#  'V021B76A': 'бился',
#  'S127A9A': 'лоры',
#  'P1267A2B': 'славе',
#  'V131A3A67A': 'погасло',
#  'C1267A28A': 'словно',
#  'V232A62B64B7': 'возвестил',
#  'S138A9A4A': 'народы',
#  'V1439A8B4B7B': 'хранители',
#  'V137B5B7B': 'лечили',
#  'V2319B37A8B7': 'преклонил',
#  'S132A7C53A': 'волюшка',
#  'A158B19B64C18A8B': 'неприступными',
#  'V025B64A4': 'чистят',
#  'V1226A4A': 'взята',
#  'S13C6A9A': 'узоры',
#  'V032JB3A7': 'выехал',
#  'S1319B42A9642A': 'притворства',
#  'A022A58AJ': 'важной',
#  'A04A12B5A7AJ': 'обветшалый',
#  'A1262A83BJ': 'звонкий',
#  'V23A8A2A7': 'омывал',
#  'V141A4A8A7A6Ь': 'подымалась',
#  'V14A4B54JC': 'одеждою',
#  'S2342B9A8B': 'дверями',
#  'S026B7B8Ь': 'зелень',
#  'A1237A48A8': 'хладном',
#  'A133A9A68AJ': 'корыстный',
#  'V13C8JB8': 'умеем',
#  'V0319B68A8A': 'признано',
#  'S1462B4B4B7B': 'свидетели',
#  'A047C1B68B3A8': 'любезником',
#  'A159A6A15A4A8B': 'рассыпчатыми',
#  'V131A2B9Ь4B': 'поверьте',
#  'A2324A7B3B': 'вдалеке',
#  'S223A8A8': 'камням',
#  'A238A6A2B4': 'назовет',
#  'A138B5C9AJ': 'мишурой',
#  'A031A1B8Ь3AJ': 'папенькой',
#  'S135B64A3A64Ь': 'жестокость',
#  'A158B69A28B8JA': 'несравненная',
#  'V039A6B64AJ': 'росистый',
#  'A13C2A7AJ': 'увялый',
#  'V2263A91B7': 'скорбел',
#  'V244A9A5B7A': 'дорожило',
#  'V241A4A8C6A': 'подтянуся',
#  'V021B96B': 'перси',
#  'V239A6JA7': 'рассеял',
#  'S221A73A8': 'полкам',
#  'V2267B1B6': 'слепец',
#  'S136C19B43A': 'субретка',
#  'V22B5C': 'ищу',
#  'S028A53B': 'мошки',
#  'V149B5JB6A': 'решается',
#  'V14A4C8A8B4': 'отуманит',
#  'V122A4B4': 'вводит',
#  'S1267A2C': 'слову',
#  'V2249C4A6Ь': 'трудясь',
#  'S029B28A64Ь': 'ревность',
#  'P224A19A': 'добро',
#  'A143C64A98B3A8': 'кустарником',
#  'S1339A7JA3': 'крылиях',
#  'V0129A8': 'вран',
#  'V239A67B5A7': 'различал',
#  'V028B968B4': 'мерзнет',
#  'V231A8B9B7': 'помирил',
#  'A027C3AJ': 'лукой',
#  'V016B8': 'зем',
#  'S136A1A9A': 'забора',
#  'A0317A8B8AJ': 'пламенной',
#  'S241A2A4A8B': 'поводами',
#  'S2219B8B9': 'пример',
#  'S149A6JA8JB': 'рассеянье',
#  'V231A2A7B4': 'повалит',
#  'A1348B49B28B': 'дмитрёвне',
#  'V222A6Ь8B5Ь': 'возьмешь',
#  'V13C4B27B8': 'удивлен',
#  'V13A6B8B4': 'осенит',
#  'A138B67A58A': 'неслышно',
#  'A041A78A58JB': 'полночное',
#  'S13A12A7A2': 'обвалов',
#  'V1268A5B4': 'значит',
#  'V14C7A18C7A6Ь': 'улыбнулась',
#  'V226B3A': 'сего',
#  'S12649C8A8': 'струнам',
#  'A2539B64A19A68A': 'крестообразно',
#  'V1319A8B38C2': 'проникнув',
#  'V22B619A2': 'избрав',
#  'V032A37JB4': 'выклюет',
#  'V13C5A7A': 'ужжало',
#  'S13A6B8B': 'осени',
#  'V139A617A5Ь6A': 'расплачься',
#  'S2268B': 'змии',
#  'V25A64A8A2B76A': 'остановился',
#  'V0138B5Ь': 'кннешь',
#  'A148B62B95B8AJ': 'низверженный',
#  'V1269B8AJ': 'зримый',
#  'V236A3B1B4': 'закипит',
#  'V2362B93JB4': 'свергает',
#  'S233A7A6A3': 'колясок',
#  'A025B25B3': 'живших',
#  'S233A7A6A2': 'голосов',
#  'A225B2A3': 'живых',
#  'S138B8C4A': 'минута',
#  'S12637A8B': 'склоне',
#  'V232B6B7A': 'весела',
#  'A235C48JC': 'чудную',
#  'S225B8C': 'чему',
#  'A14A15B98A3A': 'обширного',
#  'A151B61A3AJ8JC': 'беспокойную',
#  'S012B3': 'век',
#  'A034B2B5JA': 'девичья',
#  'V231A4B5B5Ь': 'потешишь',
#  'S222649B5B': 'встрече',
#  'V14C3A5JC': 'угасшую',
#  'S2217C4A8': 'плутам',
#  'V1339B64B4Ь6A': 'креститься',
#  'V239A6A38A7': 'разогнал',
#  'S2419B37C5B8JA': 'приключенья',
#  'S026A5B8Ь': 'сажень',
#  'A232B5B93A8': 'вечерком',
#  'S016C1': 'зуб',
#  'S02JA85B3': 'ямщик',
#  'A12649A58A3': 'страшных',
#  'S236A1A3A': 'сапога',
#  'V036A838C25B6Ь': 'сомкнувшись',
#  'A1319A4B28AJ': 'противной',
#  'V03619A2B4Ь6A': 'справиться',
#  'V22C27B3': 'увлек',
#  'V133A6B7B6Ь': 'косились',
#  'S2264A7A': 'стола',
#  'S1239A63C': 'краску',
#  'S231A9JC': 'порою',
#  'S139A61B63C': 'расписку',
#  'V2261A67B': 'спасли',
#  'S22649A64BJ': 'страстей',
#  'A0163A3': 'цкак',
#  'V23A18A7A': 'обняла',
#  'A13689A48JB': 'смрадные',
#  'A133B4AJ63AJ': 'китайской',
#  'S13A18A8A2': 'обманов',
#  'V122649B4B2': 'встретив',
#  'S155B98A39B2A3A': 'черногривого',
#  'V23A5B2A4': 'оживят',
#  'V239A54A7B': 'рождали',
#  'V129A8A': 'рана',
#  'V231C64JB4': 'пустеет',
#  'S2249A34B9': 'трактир',
#  'A145C5B6B8AJ': 'чужеземной',
#  'A135C5B8B': 'чужими',
#  'A024A83A': 'тонко',
#  'S027BJ7A': 'лейлы',
#  'A148B2A7Ь8JA': 'невольная',
#  'V02A48B6': 'отнес',
#  'A2239B64A': 'христа',
#  'V1319B4A8A': 'предана',
#  'V03A42B642CJ': 'ответствуй',
#  'A1319B58JC': 'прежнюю',
#  'S135B94B8A3': 'чертенок',
#  'A0435': 'хххш',
#  'A131B68A728A': 'безмолвно',
#  'V022B9A4': 'верят',
#  'S132A4A4A': 'ватата',
#  'V121B8A6Ь': 'пенясь',
#  'V1319B8C4B4': 'принудит',
#  'V13JA27A7A6Ь': 'являлась',
#  'V2319A4A2A7': 'продавал',
#  'V032A4JB4': 'выдает',
#  'S025B85B8': 'женщин',
#  'V146A1A2AJ6A': 'забывайся',
#  'S011JA8': 'пьян',
#  'A129A4B': 'рати',
#  'A236AC49A': 'заутра',
#  'A131A3A98A': 'покорны',
#  'V131A7A7B': 'пылали',
#  'A1237A42AJ': 'клятвой',
#  'A131B67C8AJ': 'безлунный',
#  'A1339A68JA': 'красная',
#  'A136B4A8B': 'седыми',
#  'S024A53A': 'точка',
#  'V226A43A7': 'соткал',
#  'A031B48JC': 'бедную',
#  'A028A68B94Ь': 'насмерть',
#  'V0426JB9A5B8AJ': 'взъерошенный',
#  'V2319A9A4A': 'прорыта',
#  'A1319B8A83AJ': 'приманкой',
#  'S035BJ3JC': 'шейкою',
#  'V14C37A8B7B6Ь': 'уклонились',
#  'A126A3A': 'сока',
#  'S227A9': 'лоар',
#  'A037A63JA': 'лаская',
#  'A1339C6B863A8': 'грузинском',
#  'V239A6A9A7': 'разорял',
#  'V13B8B7B': 'имели',
#  'A026B98A': 'серны',
#  'V12261A8B7': 'вспомнил',
#  'A046B9B19A8A3': 'серебряных',
#  'V24A62B5B8A': 'освещена',
#  'V23C19B3B': 'упреки',
#  'V237B48JC': 'летнею',
#  'V141A3A9A7B6Ь': 'покорялись',
#  'V2217B8A7': 'пленял',
#  'A152649B2A5B8JB': 'встревоженное',
#  'S125B93B6Ь4': 'черкесьд',
#  'A024A7Ь5B': 'дольше',
#  'V222B6B7': 'висел',
#  'V24C4A7JA': 'удаляя',
#  'A136B94B58A3': 'сердечных',
#  'V2249B5A': 'треща',
#  'V136A4B76A': 'садился',
#  'V1337A4A6A': 'глядятся',
#  'A131A9A58AJ': 'порочный',
#  'S023A53A': 'кошка',
#  'S1237A9A': 'клара',
#  'V139A69C5B4': 'разрушит',
#  'S022B68B3': 'вестник',
#  'V22A4B4': 'одет',
#  'V131A4C37A': 'потухло',
#  'V2337A8B6A': 'клянися',
#  'V034C8A7A': 'думала',
#  'N055B4A98A6A4B': 'четырнадцати',
#  'S131A3A4A': 'походы',
#  'A1239C5B': 'круче',
#  'A148B5A67B2A': 'несчастливо',
#  'V24A19B5B8A': 'обречена',
#  'V1362B95B6A': 'свершится',
#  'V13A137A5C4': 'обгложут',
#  'S221A9Ь1B': 'борьбе',
#  'A03813': 'нпх',
#  'V236A2JB4': 'сзывает',
#  'A051B5C642B8JB': 'бесчувственное',
#  'A23A5B3A': 'отчего',
#  'S1327A4B8JB': 'владенье',
#  'V021B7B5': 'пележш',
#  'A243A97A8A5B3': 'горланящих',
#  'V223B1B4': 'кипит',
#  'V23C2A8C4Ь': 'увянуть',
#  'V2263A6A2': 'сказав',
#  'A15A4B8A3JA': 'одинокая',
#  'A2437A48A39A2B8': 'хладнокровен',
#  'A228A39A4': 'наград',
#  'A031A78JB': 'полное',
#  'S15A1A6B8JB': 'опасение',
#  'V2237A5C': 'гляжу',
#  'V23A42B98C7': 'отвернул',
#  'S034A5B9JC': 'дочерью',
#  'V122649B4B7': 'встретил',
#  'V221C3A7': 'пугал',
#  'S1339B64A7B': 'кристалле',
#  'A0449B1B48JB': 'трепетное',
#  'A029A3A8': 'роком',
#  'V1349B1B5B4': 'дребезжит',
#  'S013A9': 'хор',
#  'V1269B7B': 'зрели',
#  'S131B5A7BJ': 'печалей',
#  'A021C98AJ': 'бурной',
#  'S248B1A3A4A': 'непогода',
#  'V251A68B2JB4': 'подсмеивает',
#  'S123A9C': 'гору',
#  'V038A5C6A': 'ношуся',
#  'V236A48B7A': 'затмила',
#  'S235A49JC': 'чадрою',
#  'A134B3C5BJ': 'текущий',
#  'V135A7B7A': 'жалела',
#  'S22A38B': 'окне',
#  'A15A1C64A5B8AJ': 'опустошенной',
#  'S1367A43JC': 'сладкою',
#  'V036A17B8AJ': 'зыблемый',
#  'V149B6JC6A': 'рисуются',
#  'S128B4A7': 'металл',
#  'V24A67B17JA': 'ослепляя',
#  'S2319A37A4C': 'прохладу',
#  'A15B64A5B4B7Ь8A3': 'истощительных',
#  'S234B5B8A': 'тишина',
#  'V14C5A6AJ6A': 'ужасайся',
#  'S026A2B64Ь': 'зависть',
#  'A1319B39A68A': 'прекрасны',
#  'S1268B3A': 'смеха',
#  'V22B4C': 'иду',
#  'S227C3C': 'лугу',
#  'V13B64A938C7': 'исторгнул',
#  'V124B5C6Ь': 'тешусь',
#  'S2342A9A8B': 'дворами',
#  'V231A41B6A7': 'подписал',
#  'V1219A4A4Ь': 'прятать',
#  'S134B2B6A': 'девица',
#  'V148A4JB6A': 'мотается',
#  'A048AJ4B8JA': 'найденная',
#  'V146A2A9B6A': 'заварится',
#  'V15A419A27JC6A': 'отправляются',
#  'A022A7Ь8A': 'вольна',
#  'S04C5A64JB8': 'участием',
#  'A137A3A8A3': 'лакомых',
#  'S026B96B': 'сердце',
#  'V13A7B8A': 'оленя',
#  'S1337A3A7B4': 'глаголет',
#  'V011B5Ь': 'печь',
#  'S022A73B': 'волки',
#  'V13A6B8A': 'осеня',
#  'S022B953A2': 'вершков',
#  'S1249B5B8': 'трещин',
#  'V13A64A7B': 'остыли',
#  'V23A1JA68A4Ь': 'объяснять',
#  'A052AB8642B8JB': 'воинственные',
#  'V2419B3A4B7A': 'приходила',
#  'S1268A8JC': 'знанью',
#  'A018A': 'мно',
#  'S01264B8Ь': 'вздень',
#  'S223A8A3': 'конях',
#  'A241B69A6C4B8': 'безрассуден',
#  'S131C8A3C': 'бумагу',
#  'S143A7A8A8B': 'колоннами',
#  'V14C1B2A4Ь6A': 'упиваться',
#  'V2319A3A4B7': 'проходил',
#  'A031B7A3A': 'белого',
#  'A225B2A8': 'живым',
#  'V021A25B': 'бывши',
#  'S1262C3C': 'звуку',
#  'A1419B64C18A3A': 'преступного',
#  'V131A67B48B8': 'последнем',
#  'S223A9B4': 'карет',
#  'S231A7A3A2': 'поляков',
#  'V1268A7B': 'знали',
#  'V149A54JB6A': 'рождается',
#  'V231A47B6A': 'подлеца',
#  'P01A4': 'от',
#  'V2219B57A': 'пришло',
#  'V2242A9B4': 'творит',
#  'V041A5C642A2A7': 'почувствовал',
#  'V0364B7A4Ь6A': 'сделаться',
#  'V122A6A4Ь': 'вязать',
#  'V2287JC': 'млею',
#  'S241A7C62B4A8': 'полусветом',
#  'V043A7B17C6A': 'колеблются',
#  'A136B3A48A': 'сегодня',
#  'A1428B8A4B7Ь8A3': 'внимательных',
#  'V026A27B3': 'завлек',
#  'V12BC': 'иу',
#  'S0139A8': 'кран',
#  'V236A39B5B4': 'закричит',
#  'S231B9B6AJ': 'березой',
#  'V138B4A7B6Ь': 'метались',
#  'A028A48A8': 'модном',
#  'S011A64Ь': 'бость',
#  'V1292A7A': 'рвала',
#  'V134B7C6A': 'делюся',
#  'V02JB64B4Ь': 'ездить',
#  'V0368JB5Ь6A': 'смеешься',
#  'A1319JA48AJ': 'приятный',
#  'S0267A4A64Ь': 'сладость',
#  'V22264A38C7': 'вздохнул',
#  'S1427A4A5B642A': 'владычество',
#  'S121A7B': 'поле',
#  'A147B8B2JB': 'ленивое',
#  'S138B4C3A': 'недуга',
#  'V1519A8A4A25B86A': 'промотавшимся',
#  'V022A8B8': 'вянем',
#  'A158BC3A8A8AJ': 'неугомонной',
#  'V2261C64B7': 'спустил',
#  'V246A39A7A6A': 'сокрылася',
#  'S138A4A8A': 'мадона',
#  'A2368A5A7A': 'сначала',
#  'A1339A2A2A8': 'кровавым',
#  'V1419A38B2B76A': 'прогневился',
#  'A024A28A8': 'давным',
#  'A25B638A8B5B63BJ': 'изгнаннический',
#  'V131A64B38C4Ь': 'постигнуть',
#  'A1287A4A3': 'младых',
#  'A133A2A98A': 'коварны',
#  'V12264JB4': 'встает',
#  'V13639B18C7B': 'скрипнули',
#  'S23A74A9B': 'алтаре',
#  'A221A68BJ': 'поздней',
#  'V121B5A4Ь': 'печать',
#  'A1368B94B7Ь8AJ': 'смертельный',
#  'V146A9A4B76A': 'зародился',
#  'A048B6A17B8A3': 'незыблемых',
#  'A123C4A': 'гудя',
#  'S1439A6A2B6C': 'красавицу',
#  'S014': 'т',
#  'A131B97A2AJ': 'перловой',
#  'A1237A48BJ': 'хладней',
#  'S033A94JC': 'гордою',
#  'A141A4JB8AJ': 'потаенной',
#  'V23A4A39A4Ь': 'отыграть',
#  'V232A62A4B7': 'возводил',
#  'S022A7A2': 'валов',
#  'A137B4C5BJ': 'летучей',
#  'S22A9A1': 'арап',
#  'S22A8B': 'они',
#  'A2328B6A18AJ': 'внезапной',
#  'V229B1BJ': 'репей',
#  '-02JA3': 'йак',
#  'A248B68A68JB': 'несноснее',
#  'S226B2B9': 'север',
#  'V1226A25B': 'взявши',
#  'A148A4B9B863AJ': 'материнской',
#  'A238B5B8C': 'ничему',
#  'V12264A8C4': 'встанут',
#  'A222B3A8': 'веком',
#  'S258A1A7BA8A': 'наполеона',
#  'V22A8AJ': 'оный',
#  'A238A3A8B6': 'наконец',
#  'A051B5A7A68A3A': 'безжалостного',
#  'A043C7Ь7B2JA': 'гульливая',
#  'S1261A9B': 'споре',
#  'V23C49A4B2': 'утратив',
#  'A158C6C7Ь8A863A3A': 'мусульманского',
#  'V152A4B7JB6A': 'выделяется',
#  'A13C2B9B8': 'уверен',
#  'A2362A4JA': 'святая',
#  'A2239C64A7Ь': 'хрусталь',
#  'V229A28A4Ь': 'равнять',
#  'V1419A85A25B6A': 'промчавшися',
#  'V241A1C3JB8': 'попугаем',
#  'V2267B4B7': 'следил',
#  'A232B49B7A': 'ветрилы',
#  'V24A64A27JC4': 'оставляют',
#  'S03A83B7A8': 'ангелом',
#  'A035B74A8B': 'желтыми',
#  'V226A58B4': 'сожмет',
#  'S121A49A64Ь': 'потрясть',
#  'S2217B5A8': 'плечам',
#  'S2267A2A3': 'словах',
#  'S018A5Ь': 'ночь',
#  'V134B7B76A': 'делился',
#  'S226A83A': 'сынка',
#  'A224B8A3': 'темных',
#  'V244A3A9JB4': 'догорает',
#  'S2419B2B95B86A': 'приверженцы',
#  'V233A7B17A6Ь': 'колеблясь',
#  'S028A67A': 'масла',
#  'A1419A67A27B8A3': 'прославленных',
#  'A141B6A42B48A3': 'безответных',
#  'S22A1B4': 'обед',
#  'S2468A2B4B8JA': 'сновиденья',
#  'V232B6B7B4': 'веселит',
#  'V13263A5B25B': 'вскочивши',
#  'V021A45B8': 'падшим',
#  'S03JC8A64B': 'юности',
#  'V15C4A7JC6A': 'удаляются',
#  'A2419B64C17B8JB8': 'преступленьем',
#  'V231A8B67A6Ь': 'понеслось',
#  'V141A4C35JB': 'потухшие',
#  'S221A3A4': 'поход',
#  'V226A48B7': 'затмил',
#  'V25A4A39A2AJ6A': 'отыгрывайся',
#  'V235B98JC4': 'чернеют',
#  'S1262A8JB': 'званье',
#  'V243A1B8B4B': 'кабинете',
#  'A137B8B2A': 'лениво',
#  'S2329A86C6C': 'французу',
#  'S128B7A': 'милы',
#  'V24C4A87B8A': 'утомлена',
#  'S1268A67A': 'смысла',
#  'A148B3A7A28A': 'николавна',
#  'A03649A68A3A': 'страстного',
#  'A0395A25B8AJ': 'ржавчиной',
#  'V0361A3AB4Ь': 'спокоить',
#  'A231A7Ь8A3A': 'больного',
#  'V229A67B7': 'разлил',
#  'S22A4B6': 'отец',
#  'V231A3A5C6Ь': 'покажусь',
#  'V13A4B7B': 'одели',
#  'A033A7A4B8': 'холоден',
#  'S1317C64B4B7Ь': 'блюститель',
#  'V039A4B86A': 'родимся',
#  'S05A4A38A2B8JC': 'отдохновенью',
#  'V2219A6B4Ь': 'просить',
#  'S225B4A': 'щита',
#  'A131B5A8A3': 'песчаных',
#  'A149C8A8JB': 'румяные',
#  'V136A1A4A': 'забыты',
#  'S2337B2B4C': 'клевету',
#  'V132A629A4B5Ь': 'возвратишь',
#  'V146A5A7JB5Ь': 'сожалеешь',
#  'A2349C3JB': 'другое',
#  'S02JA649B1': 'ястреб',
#  'S1359B1JA': 'жребия',
#  'A1267B2A': 'слива',
#  'S139C5BJ3A2': 'ручейков',
#  'C02JB67B': 'если',
#  'V228B7Ь38C7': 'мелькнул',
#  'A226B8BJ': 'зимней',
#  'S1239C4A8': 'крутом',
#  'A041A4A27B8AJ': 'подавленный',
#  'V1319A3A7A': 'прыгала',
#  'S131C7A4A8': 'булатом',
#  'S128A3C': 'ногу',
#  'V122B5B9183': 'вечерпнх',
#  'S1339A6A43B': 'красотки',
#  'S2226A9A3': 'взорах',
#  'V239A64A27A7': 'расставлял',
#  'S229A1A4': 'ропот',
#  'A13264A98JA': 'вздорная',
#  'S149A63JA8JA': 'раскаянья',
#  'V023C1B5Ь': 'губишь',
#  'A034A7Ь8JA': 'дальная',
#  'V131A1B54B8': 'побежден',
#  'V238A3A5B': 'накажи',
#  'A141B62C58JB': 'беззвучное',
#  'S031A4B8JB': 'паденье',
#  'S2364A9B1A': 'старипы',
#  'S2219B64A7': 'престол',
#  'S2349A68B3A2': 'тростников',
#  'S2338A3B8B': 'княгине',
#  'S127B4A': 'лета',
#  'A146B9B19B64AJ': 'серебристой',
#  'S243A9B4A9C': 'коридору',
#  'A1227B2A': 'влево',
#  'V232A8A5C': 'выношу',
#  'A13C1B4A': 'убита',
#  'V231A8B5A4Ь': 'помешать',
#  'V138B8JC4': 'меняют',
#  'A248A67A54B8BJ': 'наслаждений',
#  'S0137B5': 'клич',
#  'N2242JB': 'двое',
#  'V0489A2B7B6A': 'нравилися',
#  'S03364A41': 'кстатп',
#  'V231A45B4A7': 'поджидал',
#  'S134A8A9C': 'тамару',
#  'A028B63B': 'низки',
#  'A131B64A48A': 'бесстыдно',
#  'S1387A4B85B639': 'младенческр',
#  'S1226A9A2': 'взоров',
#  'V14C68B9B6A': 'усмирится',
#  'S236A2B7ЬB5': 'савельич',
#  'S222AJ8C': 'войну',
#  'V23C68JC': 'узнаю',
#  'V0337A8B5Ь6A': 'клонишься',
#  'V2328B8JA': 'внимая',
#  'A13A47B58AJ': 'отличный',
#  'A13C68B53AJ': 'усмешкой',
#  'V022B9B7': 'верил',
#  'V226A19C6Ь': 'запрусь',
#  'V252A6A18A2B7A6Ь': 'возобновилась',
#  'A132B9B23AJ': 'веревкой',
#  'V241B9B64A7A': 'перестало',
#  'V022A1B4Ь': 'выпить',
#  'S13C8A8B': 'умами',
#  'S023A7C1Ь': 'голубь',
#  'S158A5B2B7Ь8B3A': 'можжевельника',
#  'S224A1A9': 'топор',
#  'S1219A6C': 'прозу',
#  'V231A3A6A4Ь': 'показать',
#  'A131B617A48AJ': 'бесплодный',
#  'A029B863BJ': 'римский',
#  'S239A1A4B': 'ропоте',
#  'S23A4A8A8': 'атаман',
#  'A158B68B8JA': 'неизменная',
#  'V024C8B4': 'дунет',
#  'A166A3A74A2A8JA': 'заколдованная',
#  'V148A68A5B8A': 'назначено',
#  'V024B687B6Ь': 'тесннлись',
#  'A148A67A54B8JA3': 'наслажденьях',
#  'V041A95B2AB': 'парчевои',
#  'V2219B27B3': 'привлек',
#  'S124JA2A7': 'дьявол',
#  'N1442B8A6A4B': 'двенадцати',
#  'S131A6A9A8': 'позором',
#  'S233B9JA': 'гирея',
#  'V233A9A2A8': 'караван',
#  'S131A9A43A': 'порядка',
#  'A036B8JB': 'синее',
#  'A2267JA': 'злая',
#  'S2237C16A2': 'глупцов',
#  'V241A3A4B7A': 'походила',
#  'V13C1B4Ь6A': 'упиться',
#  'V041A3A98A64B': 'покорности',
#  'A032A649B7A8': 'выстрелам',
#  'V22A1JA7': 'объял',
#  'V249A649A17B8A': 'раздроблена',
#  'A246A2B95B8A': 'совершенно',
#  'S23649B87B8JA': 'стремленья',
#  'V23C1B9B3': 'уберег',
#  'V239A63A5B': 'расскажи',
#  'V249A68B4A7A': 'разметала',
#  'V236A39A7B': 'закрыли',
#  'S031A9C6A3': 'парусах',
#  'A145C98A7Ь8JC': 'журнальную',
#  'S221A7A8': 'былом',
#  'A138A48B8A': 'надменно',
#  'V2219A7JC4': 'прольют',
#  'S1519B41A7A5B8JA8': 'предположеньям',
#  'V2262B95B4': 'свершит',
#  'A14A4B8A3BJ': 'одинокий',
#  'A031JA963BJ': 'боярский',
#  'S0162A4': 'свод',
#  'S1319A86B4B7Ь': 'пронзитель',
#  'A1417C4A5JB': 'блудящие',
#  'A1417A5B8JA': 'блаженная',
#  'A014A818': 'томпм',
#  'V02JB64B4': 'ездит',
#  'V041A6A1A7A6Ь': 'посыпалась',
#  'S236B4A3A2': 'седоков',
#  'V236A9B2B4': 'заревет',
#  'S231A7A28C': 'баловню',
#  'S124B7A': 'тело',
#  'A222637A8C': 'взгляну',
#  'A1319A8JB': 'браное',
#  'S227B64A': 'листа',
#  'V046A1A5B2A4Ь': 'запотчевать',
#  'S231A49B4': 'патриот',
#  'V2367B4B7A': 'следила',
#  'V032A9A6B4Ь': 'выразить',
#  'A1461A6A18JB': 'способное',
#  'A2337C3JA': 'глухая',
#  'V15A37A8C7A6A': 'оглянулася',
#  'S131B6B4A': 'беседы',
#  'A138A6B8AJ': 'наземной',
#  'A022B98A': 'верны',
#  'V22B39B2': 'игрив',
#  'V131A2JC4': 'бывают',
#  'V2419B6B9JB4': 'презирает',
#  'V24A1A6A9B7': 'опозорил',
#  'S124A8B': 'тоне',
#  'V229C5JB': 'ружье',
#  'S13A4B8A3': 'оттенок',
#  'S224B7Ь6A': 'тельца',
#  'S126A7A': 'зала',
#  'S027C4A8': 'людям',
#  'V246A6A1JC': 'засыпаю',
#  'V249A6A39A76A': 'разыгрался',
#  'A133C67A98AJ': 'гуслярный',
#  'A125B48A': 'тщетны',
#  'S038B58A64B': 'нежности',
#  'V133A7C1B4': 'голубит',
#  'A229A28A': 'равны',
#  'A148A63A263B8B': 'московскими',
#  'S02A6A8': 'асом',
#  'S148A75A8JB': 'молчание',
#  'A041A5B642B8A3': 'божественных',
#  'V04B61C3A8AJ': 'испуганный',
#  'V231A1A4JBJ': 'попадьей',
#  'S015C3': 'жук',
#  'V0168A2': 'знав',
#  'A134B98A2AJ': 'терновый',
#  'A037A63A2AJ': 'ласковой',
#  'S135B93B6A2': 'черкесов',
#  'A22JB8A8': 'емон',
#  'S13C5A8B': 'ушами',
#  'A038A4C4AJ': 'надутой',
#  'V136A2A7A': 'завала',
#  'A134A2A7Ь8AJ': 'довольный',
#  'A028A2A8': 'новом',
#  'A131A4A1B8': 'подобен',
#  'S01639A': 'скры',
#  'A0362A83A3A': 'звонкого',
#  'A163A67A27JB8JA': 'гословляемая',
#  'V12264JB5Ь': 'встаешь',
#  'V134C8A8A': 'туманы',
#  'V146A39A4JC': 'закрытую',
#  'V231A47B4B4': 'подлетит',
#  'V22C39A4': 'укрыт',
#  'V148B2B4B8AJ': 'невидимой',
#  'A024B3AJ': 'тихой',
#  'A044AB8642B8AJ': 'таинственный',
#  'V136A2A4A4': 'заводят',
#  'S125A64JB': 'счастье',
#  'S021B9B3': 'берег',
#  'V023C4B4': 'гудет',
#  'A1319A2JC': 'правою',
#  ...}

# %%
from russtress import Accent
from pyphonetics import Soundex
from fonetika.soundex import RussianSoundex
import rusyllab
from fonetika.distance import PhoneticsInnerLanguageDistance
from collections import defaultdict

# %%
accent = Accent()
soundex = RussianSoundex(delete_first_letter=True, code_vowels=True)
phon_distance = PhoneticsInnerLanguageDistance(soundex)
# Out:
# WARNING:tensorflow:From /home/rokku/.local/lib/python3.6/site-packages/russtress/text_accentAPI.py:40: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
def get_rhyme_ending(word):
    stress_pos = accent.put_stress(word).find('\'')
    if stress_pos == -1:
        return word

    lst = list(word)
    lst[stress_pos-1] = lst[stress_pos-1].upper()
    word = ''.join(lst)
    sx = rusyllab.split_words([word])
    for i in range(len(sx)):
        if not sx[i].islower():
            return ''.join(sx[i:]).lower()
def is_rhyme(word1, word2):
    end1 = get_rhyme_ending(word1)
    end2 = get_rhyme_ending(word2)
    if phon_distance.distance(end1, end2) <= 1:
        return True
    else:
        return False
def check_rhyme_end_with_word(end, word):
    word_end = get_rhyme_ending(word)
    if phon_distance.distance(end, word_end) <= 1:
        return True
    else:
        return False

# %%
content = sdx_word
style_corpus_soundex = sdx_word
cache = set()
lines = []
rhymed_ends = defaultdict(list)
iteration = 0
while iteration < 1:
    iteration += 1
    lines = generate_rhyme(3000, 'люблю грозу в начале мая').split("/")
    print("generated", len(lines))
    for line in lines:
        terms = [t for t in line.split(" ") if t]
        if not terms:
            continue
        
        generated_line = []
        for term in terms[:-1]:
            guessed_words = {}
            for idx, word in content.items():
                lev_dist = levenshtein_distance(idx, term)
                if len(word) > 1 and lev_dist <= 1:
                    guessed_words[word] = lev_dist
            
            if not guessed_words:
                for idx, word in style_corpus_soundex.items():
                    lev_dist = levenshtein_distance(idx, term)
                    if lev_dist <= 1:
                        guessed_words[word] = lev_dist
                        
            if guessed_words:
                generated_line.append(sorted(guessed_words, key=guessed_words.get)[0])
        
        last_words = []
        last_term = terms[-1]
        for idx, word in content.items():
            lev_dist = levenshtein_distance(idx, last_term)
            if len(word) > 1 and lev_dist <= 1:
                last_words.append(word)
                
        generated_line_str = " ".join(generated_line)
        for last_word in last_words:
            if last_word in rhymed_ends:
                continue
            
            rhymed_end = get_rhyme_ending(last_word)
            for word in rhymed_ends.keys():
                if check_rhyme_end_with_word(rhymed_end, word):
                    rhymed_ends[word].append("{} {}".format(generated_line_str, last_word))
                    break
            else:
                rhymed_ends[last_word].append("{} {}".format(generated_line_str, last_word))
            
    print("Iteration {} completed".format(iteration))
# Out:
# S128JA S138A5A7B P012 S2239A6C V227C17C
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# generated 74
# Iteration 1 completed

# %%
for values in rhymed_ends.values():
    if len(values) > 3:
        print("-" * 30)
        for value in values:
            print(value)
# Out:
# ------------------------------
# мея начале во грозу люблю
# мея начале во грозу куплю
# страстей просится мне страдай ну
# страстей просится мне страдай ли
# земли долго сердце во как дотла
# своей ним из забытом мне ла
# окно мне потеря толпу
# земли забытом ну
# земли забытом ли
# стрела мне пали вещий ну
# стрела мне пали вещий ли
# звук долго безвестный дух долго лн
# как такой ним из лн
# свою ним из земля
# ним из мя спешу
# толпы кровь прекрасных земли
# толпы кровь прекрасных земля
# главе бедное стане ла
# главе бедное стане ну
# земли русские слеза ну
# земли русские слеза ли
# страстей ним из бросили ну
# страстей ним из бросили ли
# собрать полными мне смею ну
# собрать полными мне смею ли
# страстей того смел ну
# страстей того смел ли
# ------------------------------
# страстей просится мне страдай меж
# страстей просится мне страдай мне
# страстей просится мне страдай ни
# страстей просится мне страдай нет
# ты забыты зверь унижу
# земли забытом мне
# земли забытом ни
# земли забытом нет
# проходит сердце как ценил
# земли как забытом ни мех
# земли как забытом ни мир
# земли как забытом ни ней
# земли как забытом ни мне
# земли как забытом ни ни
# земли как забытом ни ним
# земли как забытом ни меч
# ты бросили мех
# ты бросили мир
# ты бросили ней
# ты бросили мне
# ты бросили ни
# ты бросили ним
# ты бросили меч
# своей смех нежной нежно мех
# своей смех нежной нежно мир
# своей смех нежной нежно ней
# своей смех нежной нежно мне
# своей смех нежной нежно ни
# своей смех нежной нежно ним
# своей смех нежной нежно меч
# стрела мне пали вещий мне
# стрела мне пали вещий ни
# стрела мне пали вещий нет
# стрела мне надежда кран мех
# стрела мне надежда кран мир
# стрела мне надежда кран ней
# стрела мне надежда кран мне
# стрела мне надежда кран ни
# стрела мне надежда кран ним
# стрела мне надежда кран меч
# полей так сердце унижу
# страдал ним из окне
# страдал ним из они
# страдал ним из уме
# страдал ним из коне
# забыт ним из забыты нож
# страдал ним из закрылся окне
# страдал ним из закрылся они
# страдал ним из закрылся уме
# страдал ним из закрылся коне
# главе бедное стане ни
# земли русские слеза мне
# земли русские слеза ни
# земли русские слеза нет
# страстей ним из бросили мне
# страстей ним из бросили ни
# страстей ним из бросили нет
# краю мне бросили окне
# краю мне бросили они
# краю мне бросили уме
# краю мне бросили коне
# собрать полными мне смею мне
# собрать полными мне смею ни
# собрать полными мне смею нет
# зажал ним из закрылся мех
# зажал ним из закрылся мир
# зажал ним из закрылся ней
# зажал ним из закрылся мне
# зажал ним из закрылся ни
# зажал ним из закрылся ним
# зажал ним из закрылся меч
# страстей того смел мне
# страстей того смел ни
# страстей того смел нет
# постель как плакать мех
# постель как плакать мир
# постель как плакать ней
# постель как плакать мне
# постель как плакать ни
# постель как плакать ним
# постель как плакать меч
# забыт он рыданьем мех
# забыт он рыданьем мир
# забыт он рыданьем ней
# забыт он рыданьем мне
# забыт он рыданьем ни
# забыт он рыданьем ним
# забыт он рыданьем меч
# ------------------------------
# страстей просится мне страдай вне
# земли как забытом ни сне
# земли как забытом ни дне
# ты бросили сне
# ты бросили дне
# своей смех нежной нежно сне
# своей смех нежной нежно дне
# стрела мне надежда кран сне
# стрела мне надежда кран дне
# страдал ним из змии
# страдал ним из вами
# страдал ним из закрылся змии
# страдал ним из закрылся вами
# краю мне бросили змии
# краю мне бросили вами
# зажал ним из закрылся сне
# зажал ним из закрылся дне
# постель как плакать сне
# постель как плакать дне
# забыт он рыданьем сне
# забыт он рыданьем дне
# ------------------------------
# страстей просится мне страдай на
# земли долго сердце во как томно
# земли долго сердце во как додо
# земли долго сердце во как туда
# земли долго сердце во как того
# земли долго сердце во как подо
# земли долго сердце во как тогда
# своей ним из забытом мне ко
# своей ним из забытом мне во
# своей ним из забытом мне го
# своей ним из забытом мне бы
# своей ним из забытом мне до
# своей ним из забытом мне ха
# своей ним из забытом мне со
# земли как та
# земли как наг
# звон ножен мне строчил дом во го
# звон ножен мне строчил дом во наг
# окно мне потеря толпы
# земли как забытом ни мя
# коня мне долго во
# сидит нос подержит ним со
# как ним со
# сидит как ним со
# ты бросили мя
# белого могиле во
# своей смех нежной нежно мя
# звук долго безвестный дух долго нам
# потупя мя мне поражал го
# потупя мя мне поражал наг
# стрела мне надежда кран мя
# земли белого света го
# земли белого света наг
# как такой ним из нам
# страдал ним из она
# свою ним из семья
# ним из мя спеша
# звон нежным из повисший го
# звон нежным из повисший наг
# забыт ним из забыты нам
# забыт ним из забыты мя
# забыт ним из забыты мор
# забыт ним из забыты мох
# забыт ним из забыты мной
# забыт ним из забыты нов
# забыт ним из забыты нос
# звук долго мерно проходил ним со
# любви их ним со
# золотом напрасных земли во
# страдал ним из закрылся она
# главе бедное стане ко
# главе бедное стане во
# главе бедное стане мно
# главе бедное стане бы
# главе бедное стане мя
# главе бедное стане до
# главе бедное стане со
# главе бедное стане над
# главе бедное стане но
# земли полными нежным го
# земли полными нежным наг
# земли бездною из свете во
# краю мне бросили она
# зажал ним из закрылся мя
# страдай мне пристает нос во
# постель как плакать мя
# забыт он удержит ним со
# забыт он рыданьем мя
# ------------------------------
# страстей просится мне страдай де
# страстей просится мне страдай же
# земли как тих
# окно мне потеря талье
# окно мне потеря толпе
# земли забытом же
# проходит сердце как следил
# проходит сердце как сидим
# проходит сердце как светил
# проходит сердце как задел
# проходит сердце как сидит
# проходит сердце как летел
# проходит сердце как сетиз
# проходит сердце как судил
# проходит сердце как сидел
# земли мне скажи
# земли как забытом ни бе
# земли как забытом ни чи
# земли как забытом ни ке
# земли как забытом ни ти
# земли как забытом ни се
# ты бросили бе
# ты бросили чи
# ты бросили ке
# ты бросили ти
# ты бросили се
# своей смех нежной нежно бе
# своей смех нежной нежно чи
# своей смех нежной нежно ке
# своей смех нежной нежно ти
# своей смех нежной нежно се
# стрела мне пали вещий же
# стрела мне надежда кран бе
# стрела мне надежда кран чи
# стрела мне надежда кран ке
# стрела мне надежда кран ти
# стрела мне надежда кран се
# страдал ним из ахи
# ним из мя спеши
# толпы кровь прекрасных семье
# толпы кровь прекрасных семьи
# страдал ним из закрылся ахи
# земли русские слеза же
# страстей ним из бросили же
# краю мне бросили ахи
# молодой заране тот проходил
# собрать полными мне смею же
# зажал ним из закрылся бе
# зажал ним из закрылся чи
# зажал ним из закрылся ке
# зажал ним из закрылся ти
# зажал ним из закрылся се
# страстей того смел же
# постель как плакать бе
# постель как плакать чи
# постель как плакать ке
# постель как плакать ти
# постель как плакать се
# ней во забытом ни мне скажи
# забыт он рыданьем бе
# забыт он рыданьем чи
# забыт он рыданьем ке
# забыт он рыданьем ти
# забыт он рыданьем се
# ------------------------------
# свод ножен ни кран потеря
# свод ножен ни кран потерян
# земли бездною надета
# страсть забыты мне потерян
# ------------------------------
# земли как дый
# земли как ток
# земли как там
# земли как так
# земли как тот
# звон ножен мне строчил дом во гой
# звон ножен мне строчил дом во так
# звук долго безвестный дух долго дом
# потупя мя мне поражал гой
# потупя мя мне поражал так
# земли белого света гой
# земли белого света так
# как такой ним из дом
# звон нежным из повисший гой
# звон нежным из повисший так
# земли полными нежным гой
# земли полными нежным так
# ним из покинет нос на страдай
# ------------------------------
# земли как как
# земли как бок
# звон ножен мне строчил дом во гак
# звон ножен мне строчил дом во цкак
# звон ножен мне строчил дом во ком
# звон ножен мне строчил дом во бок
# звук долго безвестный дух долго гам
# потупя мя мне поражал гак
# потупя мя мне поражал цкак
# потупя мя мне поражал ком
# потупя мя мне поражал бок
# земли белого света гак
# земли белого света цкак
# земли белого света ком
# земли белого света бок
# как такой ним из гам
# звон нежным из повисший гак
# звон нежным из повисший цкак
# звон нежным из повисший ком
# звон нежным из повисший бок
# земли полными нежным гак
# земли полными нежным цкак
# земли полными нежным ком
# земли полными нежным бок
# ------------------------------
# сидит нос подержит ним из
# сидит нос подержит ним тс
# как ним тс
# сидит как ним тс
# звук долго безвестный дух долго им
# звук долго безвестный дух долго аз
# как такой ним из им
# как такой ним из аз
# забыт ним из забыты аз
# звук долго мерно проходил ним тс
# любви их ним тс
# забыт он удержит ним тс
# ------------------------------
# земли бездною надежда
# земли бездною надеждой
# земли бездною одежда
# земли бездною надеждах
# ------------------------------
# звук долго безвестный дух долго ром
# звук долго безвестный дух долго сон
# звук долго безвестный дух долго вам
# звук долго безвестный дух долго он
# как такой ним из сон
# как такой ним из вам
# как такой ним из он
# забыт ним из забыты раз
# ------------------------------
# нос на сломится мне забыты
# нос на сломится мне забота
# нос на сломится мне забыла
# нос на сломится мне забытом

# %%
rhymed_ends
# Out:
# defaultdict(list,
#             {'мея': ['люблю грозу во начало мея',
#               'люблю грозу во начало нею',
#               'люблю грозу во начало боя',
#               'люблю грозу во начало муя',
#               'люблю грозу во начало чуя',
#               'и долго мя оставит мя',
#               'со себя пали мя'],
#              'тебе': ['стоял он тебе',
#               'стоял он пебо',
#               'стоял он себя',
#               'стоял он тебя',
#               'садится мех земля ни знающей земле',
#               'садится мех тебе столбы',
#               'мя бросали такой запел',
#               'и голос странник как земле',
#               'со меня садится труд прости',
#               'со меня садится труд проси',
#               'со меня садится труд пройти',
#               'его браниться мир давно запел',
#               'как голос скачут голос мне',
#               'как голос скачут голос бег',
#               'ни мя стоял со мне',
#               'со себя пали мне',
#               'со себя пали мпе',
#               'со себя пали ни',
#               'со себя пали се',
#               'со себя пали ке',
#               'тогда ни стынет всё пробил',
#               'тогда ни стынет всё проси'],
#              'дела': ['стоял он дела',
#               'стоял он девы',
#               'стоял он тепла',
#               'стоял он дитя',
#               'садится мех тебе дала',
#               'садится мех тебе стола',
#               'садится мех тебе спала',
#               'садится мех тебе сняла',
#               'садится мех тебе ждала',
#               'садится мех тебе звала',
#               'садится мех тебе стыда',
#               'могилой книг безумный головы',
#               'и долго всё пришло того',
#               'и долго мя оставит ты',
#               'и долго мя оставит вы',
#               'она бродил его стрелок',
#               'горят он взор со мех глава',
#               'горят он взор со мех сова',
#               'горят он взор со мех слова',
#               'его забыты сердце была',
#               'мя плачу мя садится ты',
#               'катался дикий колокола',
#               'катался дикий колоколов',
#               'и долго взор безмолвно та',
#               'так стан цвета',
#               'хранил он была',
#               'как мя погибнуть лицо',
#               'как мя погибнуть следа',
#               'как мя погибнуть слеза'],
#              'семей': ['садится мех земля ни знающей семей',
#               'садится мех земля ни знающей землей',
#               'она печали ни струей',
#               'и голос странник как землей',
#               'невинна бросил он стариной',
#               'и долго всё пришло домой',
#               'зачем его земле мои кистей',
#               'зачем его земле мои костей',
#               'зачем его земле мои когтей',
#               'как голос скачут голос ней',
#               'как голос скачут голос мех',
#               'как голос скачут голос мир',
#               'как голос скачут голос ним',
#               'как голос скачут голос нег',
#               'как голос скачут голос меч',
#               'ни мя стоял со ней',
#               'ни мя стоял со нем',
#               'ни мя стоял со мех',
#               'ни мя стоял со мир',
#               'ни мя стоял со ним',
#               'ни мя стоял со меч',
#               'дала он пробегал страстей',
#               'со себя пали ней',
#               'со себя пали мех',
#               'со себя пали мир',
#               'со себя пали ним',
#               'со себя пали меч',
#               'он бродили такой пера ценой',
#               'тогда ни стынет всё бранил',
#               'ни страсти ни струей'],
#              'стало': ['садится мех тебе стало',
#               'садится мех тебе встала',
#               'могилой знак преступной стол',
#               'оставит жизни дикий стол',
#               'вокруг она стоял он голос стал',
#               'вокруг она стоял он голос столб',
#               'вокруг она стоял он голос стол'],
#              'молодым': ['как голос странник молодым',
#               'как голос странник налитой',
#               'как голос странник молодой',
#               'как голос странник молодых',
#               'как голос странник золотой',
#               'могилой знак преступной дом',
#               'могилой знак преступной сын',
#               'могилой знак преступной стан',
#               'могилой знак преступной стон',
#               'как голос странник налитой',
#               'как голос странник молодой',
#               'как голос странник молодых',
#               'как голос странник золотой',
#               'оставит жизни дикий дом',
#               'оставит жизни дикий сын',
#               'оставит жизни дикий стан',
#               'оставит жизни дикий стон',
#               'и долго всё пришло таком',
#               'вокруг она стоял он голос дал',
#               'вокруг она стоял он голос стан',
#               'и всё какой и дар',
#               'горят он взор со мех словам',
#               'как голос странник налитой',
#               'как голос странник молодой',
#               'как голос странник молодых',
#               'как голос странник золотой',
#               'во цепи налитой',
#               'во цепи молодой',
#               'во цепи молодых',
#               'во цепи золотой',
#               'как голос странник налитой',
#               'как голос странник молодой',
#               'как голос странник молодых',
#               'как голос странник золотой',
#               'как голос странник налитой',
#               'как голос странник молодой',
#               'как голос странник молодых',
#               'как голос странник золотой',
#               'мя плачу мя садится дом',
#               'мя плачу мя садится дам',
#               'мя плачу мя садится тем',
#               'мя плачу мя садится там',
#               'мя плачу мя садится дням',
#               'мя плачу мя садится дум',
#               'мя плачу мя садится сын',
#               'мя плачу мя садится он',
#               'мя плачу мя садится дпом',
#               'мя плачу мя садится вам',
#               'мя плачу мя садится дол',
#               'мя плачу мя садится стон',
#               'мя плачу мя садится нам',
#               'мя плачу мя садится дар',
#               'мя плачу мя садится ток',
#               'мя плачу мя садится ром',
#               'и долго взор безмолвно так',
#               'и долго взор безмолвно там',
#               'и долго взор безмолвно той',
#               'и долго взор безмолвно тот',
#               'и долго взор безмолвно ток',
#               'ни мя стоял со тем',
#               'ни мя стоял со нам',
#               'он бродили такой пера седых',
#               'он бродили такой пера четой',
#               'он бродили такой пера седой',
#               'он бродили такой пера седым',
#               'он бродили такой пера свитой',
#               'он повелел себя прочитал',
#               'он повелел себя пролетал',
#               'он повелел себя поведал',
#               'садится телом налитой',
#               'садится телом молодой',
#               'садится телом молодых',
#               'садится телом золотой',
#               'ни стынет гор такой престол',
#               'ни стынет гор такой крестов',
#               'как мя погибнуть слезам'],
#              'забыт': ['мя бросали такой забыт',
#               'мя бросали такой запас',
#               'мя бросали такой забыл',
#               'мя бросали такой забыв',
#               'мя бросали такой попал',
#               'и всё какой и бор',
#               'и всё какой и год',
#               'и долго мя оставит яд',
#               'его браниться мир давно запас',
#               'его браниться мир давно забыл',
#               'его браниться мир давно забыв',
#               'его браниться мир давно попал',
#               'и долго взор безмолвно бок',
#               'она столбы прошло моей зарыт',
#               'и всё домой рукой стоят'],
#              'завыл': ['мя бросали такой завыл',
#               'грозят и ветры долго вор',
#               'и зверь печальной головой',
#               'могилой книг безумный головой',
#               'могилой книг безумный головах',
#               'вокруг она стоял он голос зол',
#               'вокруг она стоял он голос звал',
#               'и всё какой и вор',
#               'горят он взор со мех словах',
#               'и голос чуждый головой',
#               'и всё домой рукой стоял',
#               'и всё домой рукой сеял',
#               'тогда ни стынет всё провел'],
#              'стран': ['могилой знак преступной стран',
#               'могилой знак преступной срам',
#               'оставит жизни дикий срам',
#               'бессильной знак преступной строк',
#               'бессильной знак преступной строй',
#               'бессильной знак преступной страд',
#               'бессильной знак преступной страж',
#               'бессильной знак преступной строг'],
#              'звон': ['могилой знак преступной звон',
#               'могилой знак преступной злом',
#               'горит из сын первый свод',
#               'оставит жизни дикий злом',
#               'и каллы он которых свод'],
#              'стор': ['могилой знак преступной стор',
#               'могилой знак преступной стыд',
#               'грозят и ветры долго вздор',
#               'грозят и ветры долго ссор',
#               'оставит жизни дикий стыд',
#               'вокруг она стоял он голос став',
#               'вокруг она стоял он голос стар',
#               'вокруг она стоял он голос стад',
#               'вокруг она стоял он голос стой',
#               'и всё какой и скор',
#               'и всё какой и ссор'],
#              'старинной': ['невинна бросил он старинной',
#               'невинна бросил он старинных'],
#              'прижалась': ['садится мех старик прижалась',
#               'садится мех старик примчалась',
#               'садится мех старик решалась'],
#              'взор': ['грозят и ветры долго взор'],
#              'колясок': ['и зверь печальной колясок',
#               'и зверь печальной голосов',
#               'и всё какой и гак',
#               'как голос скачут голос сек',
#               'как голос скачут голос ног',
#               'и долго взор безмолвно как',
#               'и голос чуждый голосов',
#               'бессильной знак преступной срок',
#               'ни стынет гор такой призыв',
#               'как мя погибнуть слезах',
#               'как мя погибнуть слезой'],
#              'пролетел': ['стоял он стон его пролетел',
#               'стоял он стон его проводил',
#               'со меня садится труд простит',
#               'могилой казни бродили',
#               'как голос скачут голос дик',
#               'и долго взор безмолвно тих',
#               'тогда ни стынет всё присел',
#               'тогда ни стынет всё спросил',
#               'тогда ни стынет всё просил',
#               'тогда ни стынет всё прошел',
#               'тогда ни стынет всё грозил',
#               'тогда ни стынет всё пролил',
#               'тогда ни стынет всё бродил',
#               'мя пронеслась ни бродили'],
#              'картину': ['и голос бедной картину'],
#              'свист': ['горит из сын первый свист',
#               'горит из сын первый свет',
#               'и каллы он которых свет'],
#              'рвет': ['горит из сын первый рвет',
#               'горит из сын первый вид',
#               'и каллы он которых вид'],
#              'сед': ['горит из сын первый сед',
#               'ни мя стоял со сем',
#               'тогда ни стынет всё бросив'],
#              'последний': ['всегда преступной свет последний',
#               'всегда преступной свет последних',
#               'всегда преступной свет последним'],
#              'такой': ['и долго всё пришло такой',
#               'и долго всё пришло дугой',
#               'и долго всё пришло тоской',
#               'и долго всё пришло какой',
#               'и долго всё пришло таков',
#               'и долго всё пришло покой',
#               'и всё какой и гор',
#               'садится мех людей и край',
#               'она столбы прошло моей зарой',
#               'она столбы прошло моей сырой',
#               'и долго всё край'],
#              'скал': ['вокруг она стоял он голос скал',
#               'вокруг она стоял он голос зпал',
#               'вокруг она стоял он голос снял',
#               'вокруг она стоял он голос слыл'],
#              'ждал': ['вокруг она стоял он голос ждал'],
#              'встал': ['вокруг она стоял он голос встал',
#               'он повелел себя проведал'],
#              'сомненья': ['и песни первые сомненья',
#               'и песни первые сомненье',
#               'и песни первые гоненье',
#               'и песни первые сомненье',
#               'и песни первые гоненье'],
#              'смеет': ['садится мех земля ни смеет',
#               'садится мех земля ни зпает',
#               'садится мех земля ни змеей',
#               'садится мех земля ни знают',
#               'садится мех земля ни зреет'],
#              'горд': ['и всё какой и горд'],
#              'кур': ['и всё какой и кур'],
#              'жар': ['и всё какой и жар', 'и всё какой и мор'],
#              'слава': ['горят он взор со мех слава'],
#              'бросали': ['могилой казни бросали',
#               'могилой казни пронзили',
#               'могилой казни грозили',
#               'и победил себя внимали',
#               'его забыты сердце пали',
#               'хранил он пали',
#               'мя пронеслась ни пронзили',
#               'мя пронеслась ни грозили'],
#              'бранили': ['могилой казни бранили', 'и победил себя сменили'],
#              'забытой': ['ни на земле забытой'],
#              'запомнят': ['ни на земле запомнят'],
#              'книг': ['как голос скачут голос книг',
#               'как голос скачут голос снег',
#               'как голос скачут голос вник'],
#              'их': ['как голос скачут голос их',
#               'как голос скачут голос лег',
#               'как голос скачут голос век',
#               'как голос скачут голос рек',
#               'как голос скачут голос щек',
#               'ни мя стоял со им'],
#              'мук': ['как голос скачут голос мук'],
#              'жала': ['его забыты сердце жала',
#               'его забыты сердце поля',
#               'его забыты сердце было',
#               'хранил он поля',
#               'хранил он было'],
#              'пяпя': ['его забыты сердце пяпя'],
#              'пела': ['его забыты сердце пела'],
#              'полю': ['его забыты сердце полю'],
#              'презирать': ['со мех молчанье презирать'],
#              'захочет': ['и во шелом проснулась ни захочет',
#               'и во шелом проснулась ни заплачет',
#               'он повелел его заплачет'],
#              'чин': ['ни мя стоял со чин', 'ни мя стоял со кем'],
#              'грот': ['садится мех людей и грот',
#               'садится мех людей и храм',
#               'садится мех людей и грыз',
#               'садится мех людей и кров',
#               'садится мех людей и гроб',
#               'и долго всё храм',
#               'и долго всё грыз',
#               'и долго всё кров',
#               'и долго всё гроб'],
#              'сваты': ['так стан сваты', 'так стан света'],
#              'свете': ['так стан свете', 'так стан свету'],
#              'гвидо': ['так стан гвидо'],
#              'свиток': ['так стан свиток', 'так стан светом'],
#              'слита': ['так стан слита'],
#              'дни': ['со себя пали дни', 'со себя пали сне'],
#              'зарос': ['она столбы прошло моей зарос'],
#              'стоя': ['и всё домой рукой стоя'],
#              'бросил': ['тогда ни стынет всё бросил'],
#              'страдание': ['и битвах первые страдание',
#               'и битвах первые страданью',
#               'и битвах первые страданье',
#               'и битвах первые страданья'],
#              'смерть': ['один лишь сердце прожег смерть'],
#              'месть': ['один лишь сердце прожег месть'],
#              'отвечает': ['какой законе отвечает', 'какой законе освещает'],
#              'ветре': ['и ветре', 'и ветр', 'и ветры'],
#              'ветер': ['и ветер']})

# %%
s = 'люблю грозу в начале мая'
for item in rhymed_ends:
    if is_rhyme(item, 'мая'):
        for line in rhymed_ends[item]:
            print(s)
            print(line)
            print('-'*30)
# Out:
# люблю грозу в начале мая
# люблю грозу во начало мея
# ------------------------------
# люблю грозу в начале мая
# люблю грозу во начало нею
# ------------------------------
# люблю грозу в начале мая
# люблю грозу во начало боя
# ------------------------------
# люблю грозу в начале мая
# люблю грозу во начало муя
# ------------------------------
# люблю грозу в начале мая
# люблю грозу во начало чуя
# ------------------------------
# люблю грозу в начале мая
# и долго мя оставит мя
# ------------------------------
# люблю грозу в начале мая
# со себя пали мя
# ------------------------------

# %%
import nltk
def encode(word):
    sdx = soundex.transform(word)

    accent_letter = accent.put_stress(word).find('/')
    rel_accent = accent_letter / len(word)
    num_syl = len(rusyllab.split_words(word.split()))
    if rel_accent <= 0.4:
        rel_accent = 0
    elif rel_accent <= 0.67:
        rel_accent = 1
    else:
        rel_accent = 2

    _, pos = nltk.pos_tag([word], lang="rus")[0]
       
    if pos in ("NONLEX"):
        return "-{}{}{}".format(rel_accent, num_syl, sdx)
    return "{}{}{}{}".format(pos[0], rel_accent, num_syl, sdx)

# %%
def encode_sent(sent, size):
    encoded = []
    for word in sent.split():
        encoded.append(encode(word))
    encoded_str =  ' '.join(encoded[::-1])
    print(encoded_str)
    encoded_str += ' /'
    if len(encoded_str) >= size:
        return encoded_str[len(encoded_str)-size:]
    else:
        return (' ' * (size-len(encoded_str))) + encoded_str

# %%
encode_sent('люблю грозу в начале мая', 40)
# Out:
# S128JA S138A5A7B P012 S2239A6C V227C17C
# '128JA S138A5A7B P012 S2239A6C V227C17C /'

# %%
encode('во')
# Out:
# 'P012A'

# %%
words_list = list(sdx_word.values())

# %%
len(words_list)
# Out:
# 22202

# %%
rhymed = []
for i, word in enumerate(words_list):
    if i % 100 == 0:
        print(i)
    if is_rhyme(word, 'мая'):
        rhymed.append(word)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-6a93de0bd292> in <module>
#       3     if i % 100 == 0:
#       4         print(i)
# ----> 5     if is_rhyme(word, 'мая'):
#       6         rhymed.append(word)
#
# <ipython-input-12-42a170a20545> in is_rhyme(word1, word2)
#      12             return ''.join(sx[i:]).lower()
#      13 def is_rhyme(word1, word2):
# ---> 14     end1 = get_rhyme_ending(word1)
#      15     end2 = get_rhyme_ending(word2)
#      16     if phon_distance.distance(end1, end2) <= 1:
#
# <ipython-input-12-42a170a20545> in get_rhyme_ending(word)
#       1 def get_rhyme_ending(word):
# ----> 2     stress_pos = accent.put_stress(word).find('\'')
#       3     if stress_pos == -1:
#       4         return word
#       5
#
# ~/.local/lib/python3.6/site-packages/russtress/text_accentAPI.py in put_stress(self, text, stress_symbol)
#     131                     pass
#     132                 else:
# --> 133                     accented_phrase.append(self.__predict(w))
#     134             final = []
#     135
#
# ~/.local/lib/python3.6/site-packages/russtress/text_accentAPI.py in __predict(self, word)
#      76             x[0, pos, CHAR_INDICES[letter]] = 1
#      77         # print(x)
# ---> 78         preds = self.model.predict(x, verbose=0)[0]
#      79         preds = preds.tolist()
#      80         max_value = max(preds)
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
print(rhymed)

# %%
def generate_rhyme(count, sent):
    generated = ""
    sentence = encode_sent(sent, maxlen)
    generated += sentence

    for i in range(count):
        x = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x[0, t, char_indices[char]] = 1.

        preds = model.predict(x, verbose=0)[0]
        next_index = sample(preds, 0.2)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char
    return generated

# %%
s = 'люблю грозу в начале мая'

# %%
generate_rhyme(1000, s)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# '227C17C S2239A6C P012 S138A5A7B S128JA \\ S01JA V011A7 S226B87B A1319B48B58A V2319A6B7B \\ C01B S022B49A8 S025B68B A141B6A1A4A8 \\ A013A3 S01JA V136A4B4B4 P018B V22649JBJ \\ C01B A024B3BJ S0164A7 A013A3 S023A7A6 A021A58AJ S0168A3 A1319B64C18AJ S01649A3 \\ P018B V23A439JC4 S01A8 V2319A3A5B4 V22649A4A4Ь \\ C01B S023A7A6 S014B3 A131A3A58AJ S0167A2 \\ V2239A6A2 C01B S023A7A6 S12649A64B S0162B4 \\ A224A3AJ S226B87B A1319B4A48A V1219B4AJ S0126A9 \\ C01B S021B42A3 A021B7Ь8AJ S018B3 S2264A9A3 \\ A013A3 S023A7A6 S12649A8B3 V2319A1B5A7 \\ S01JA V2319A2B4B7 P016A S018B3 S138A75A8JB \\ S2239A6AJ S01A8 V021A8B6 P012 S018BJ A2262JC \\ A013A3 S023A7A6 V12639A5B4 S013A9 \\ S2237A6A V133A6A7A6Ь S0134A P016A S018B3 \\ A013A3 S01JA V13C68JB4 S025B642A3 S0168A3 \\ A22A4B8 P018B V1264A8B4 S01JA S22A8A \\ S226B87A A2368A3A8A S227B6A V223A9B4 \\ S01A8 V2319A2B7B A234B5B8A S014A \\ S22A8A V136A4B6A S018B3 S2264A9B3 \\ S01JA V0168A7 A138B2B48A V14C68B8A7A \\ C01B V022B4B7 S01A8 A133A4A9AJ S018B3 \\ A013A3 S0126A9 A224A3AJ V2419B6B938JB4 \\ C01B A024A73A S0126B V2239A6A4 A'

# %%
content = sdx_word
style_corpus_soundex = sdx_word
generated = generate_rhyme(1000, s).split()
print(generated)
for term in generated:
    if term == "/":
        print(term)
        continue
        
    guessed_words = {}
    for idx, word in content.items():
        lev_dist = levenshtein_distance(idx, term)
        if len(word) > 1 and lev_dist <= 1:
            guessed_words[word] = lev_dist
           
    if not guessed_words:
        for idx, word in style_corpus_soundex.items():
            lev_dist = levenshtein_distance(idx, term)
            if lev_dist <= 1:
                guessed_words[word] = lev_dist
    
    print(sorted(guessed_words, key=guessed_words.get)[0] if guessed_words else "", end=" ")
# Out:
# S128JA S138A5A7B P012 S2239A6C V227C17C
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# ['128JA', 'S138A5A7B', 'P012', 'S2239A6C', 'V227C17C', '/', 'V22649A4A4Ь', 'A038B58JB', 'A028A5B8', 'P018B', '/', 'S226B87B', 'A031B68JC', 'P016', 'V131A4B5BJ', '/', 'S22649A64BJ', 'V1319B1B5B4', 'S018B8', 'P016', 'A228A58A', '/', 'S22649A64BJ', 'V131A3A8B5Ь', 'S014A', 'S014A', '/', 'S014A', 'V131A39A7A6Ь', 'A013A3', 'V121A7B', 'P012', 'C01B', '/', 'S226A1A4', 'A014A4', 'S138A8B8JB', 'S018B', 'P013A', '/', 'S226B87B', 'A031B9B3AJ', 'A028A5B8', 'P018B', '/', 'S0162C3', 'A024A73A', 'A024A73A', 'S138A4B7B', 'P012', '/', 'S226B1B', 'P012', 'V22649A6A', 'V22649A64AJ', 'S018B8', 'P016', 'C0154A', '/', 'S018B8', 'P016', 'V131A4B67B6Ь', 'S018B', 'V131A4B9A', '/', 'V226B4B4', 'S018A6', 'P018A', 'V226B4B4', 'S018B8', 'P016', 'C01B', '/', 'S0162C3', 'A023A9Ь3B3', 'S1319A64B8JB', 'S018B', 'V231A4A8C7', '/', 'S0162A8', 'A028A5B8', 'S018B', 'V2219B64A7', 'S018B8', 'P016', 'C01B', '/', 'S014C3', 'A024A73A', 'V131A4C8A', 'A224A3A', '/', 'S0126A9', 'V13C2B9B4', 'S018B8', 'P016', 'V131A4A75B8', 'A013A3', '/', 'S226B87B', 'A031A78JB', 'V131A4C8A', '/', 'S22649A64BJ', 'A039C63B8B', 'P012', 'V1319A3A4B7', 'S018B', '/', 'S0137A6', 'A029A48AJ', 'S226B8JA', 'S226B87B', 'P012', '/', 'V226A5A7', 'S014B8Ь', 'A024A73A', 'S128B1A', 'V13C67A5B4', '/', 'S221AJ6A', 'A1419B39A68JB', 'S018B', '/', 'V22649A7A', 'S018B', 'V1319B64B76A', 'S018B', 'V231A39A7B6Ь', '/', 'S0162B4', 'A013A3', 'S01A8', 'V131A4A8JB8', 'V0168BJ', 'C01B', '/', 'V22649A6A', 'A2262JBJ', 'S0162C3', 'A024A7']
# мея начале во грозу люблю /
# страдать нежное ножен ни /
# земли бездною из повисший /
# страстей дребезжит ним из ночных /
# страстей  ты ты /
# ты закралась как пали во и /
# забот тот сомненье мне ко /
# земли  ножен ни /
# звук долго долго недели во /
# цепи во  страдай ним из что /
# ним из  мне потеря /
# сидит нос на сидит ним из и /
# звук горьких  мне подымал /
# звон ножен мне предстал ним из и /
# дух долго потупя того /
# взор увидит ним из одолжен как /
# земли полное потупя /
# страстей русскими во проходил мне /
# глаз ратный семья земли во /
# зажал день долго небо услышит /
# бойцы прекрасное мне /
# стрела мне простился мне поклялись /
# цвет как он рыданьем змей и /
#  своей звук
